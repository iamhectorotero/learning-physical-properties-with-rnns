# %%
import matplotlib.pyplot as plt
from generate_passive_simulations import *
from toddler.action_coding import get_mouse_action, mass_answers, force_answers

# %%
from isaac.visualization import make_frame_curried
import moviepy.editor as mpy
# Out:
# pygame 1.9.6
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
from isaac.dataset import read_dataset

# %%
replays = read_dataset("replays.h5")
# Out:
# 100%|██████████| 10/10 [00:00<00:00, 207.48it/s]

# %%
print(len(replays))
# Out:
# 10

# %%
lengths = [len(trial) for trial in replays]
control = [(trial.idControlledObject.isin(["object1", "object2"])).sum() for trial in replays]

# %%
control
# Out:
# [0, 29, 103, 0, 1, 0, 50, 2, 19, 0]

# %%
max(control), np.argmax(control)
# Out:
# (103, 2)

# %%
random_trial = np.argmax(control)
# random_trial = np.random.randint(len(replays))
trial_data = replays[random_trial]

# %%
random_trial, len(trial_data), trial_data.ground_truth.unique()[0]
# Out:
# (2, 1001, 'A is heavier')

# %%
duration = len(trial_data)
rem = duration % 60

make_frame = make_frame_curried(trial_data)
clip = mpy.VideoClip(make_frame, duration=duration // 60)
clip.ipython_display(fps=60)
# Out:
# 100%|█████████▉| 960/961 [00:05<00:00, 160.06it/s]
# <div align=middle><video src='data:video/mp4;base64,...' controls>Sorry, seems like your browser doesn't support HTML5 audio/video</video></div>
